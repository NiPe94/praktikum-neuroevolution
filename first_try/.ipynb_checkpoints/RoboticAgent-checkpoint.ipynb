# %%
import gym
import pybullet_envs
import numpy as np
import neat
import pickle
import random
import matplotlib.pyplot as plt

random.seed(0)
#spec = gym.envs.registry.spec('HumanoidBulletEnv-v0')
#spec._kwargs['render'] = True
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation,
                     'data/config-humanoid')
p = neat.Population(config)
p.add_reporter(neat.StdOutReporter(True))
stats = neat.StatisticsReporter()
p.add_reporter(stats)

# %%
# for parallel evaluating:
class Worker(object):
    def __init__(self, genome, config):
        self.genome = genome
        self.config = config
        
    def work(self):

        self.env = gym.make('AntBulletEnv-v0')
        self.env.seed(0)
        self.env.reset()
        
        ac = self.env.action_space.sample()

        ob, _, _, _ = self.env.step(ac)

        done = False

        net = neat.nn.recurrent.RecurrentNetwork.create(self.genome, self.config)
        
        current_max_fitness = 0
        fitness_current = 0
        frame = 0
        counter = 0

        finallyCounter = 5000

        while not done:
            
            frame += 1

            nnOutput = net.activate(ob)

            ob, rew, done, info = self.env.step(nnOutput)
            
            fitness_current += rew
            
            if fitness_current > current_max_fitness:
                current_max_fitness = fitness_current
                counter = 0
            else:
                counter += 1
                
            finalReached = (counter>=finallyCounter)
            
                
            if done or finalReached:
                done = True
                print('fitness: '+str(fitness_current)+' counter: '+str(counter))
                
        return fitness_current

# %%
def eval_genomes(genome, config):
    worky = Worker(genome, config)
    return worky.work()

# %%
def plot_stats(statistics, ylog=False, view=False, filename='avg_fitness.svg'):
    """ Plots the population's average and best fitness. """
    if plt is None:
        warnings.warn("This display is not available due to a missing optional dependency (matplotlib)")
        return

    generation = range(len(statistics.most_fit_genomes))
    best_fitness = [c.fitness for c in statistics.most_fit_genomes]
    avg_fitness = np.array(statistics.get_fitness_mean())
    stdev_fitness = np.array(statistics.get_fitness_stdev())

    plt.plot(generation, avg_fitness, 'b-', label="average")
    plt.plot(generation, avg_fitness - stdev_fitness, 'g-.', label="-1 sd")
    plt.plot(generation, avg_fitness + stdev_fitness, 'g-.', label="+1 sd")
    plt.plot(generation, best_fitness, 'r-', label="best")

    plt.title("Population's average and best fitness")
    plt.xlabel("Generations")
    plt.ylabel("Fitness")
    plt.grid()
    plt.legend(loc="best")
    if ylog:
        plt.gca().set_yscale('symlog')

    plt.savefig(filename)
    if view:
        plt.show()

    plt.close()

# %%
pe = neat.ParallelEvaluator(8, eval_genomes)

winner = p.run(pe.evaluate)

with open('winnerPara.pkl', 'wb') as output:
    pickle.dump(winner, output, 1)
    
with open('winnerPara.pkl','rb') as readWinner:
    winner = pickle.load(readWinner)
    print('\nBest genome:\n{!s}'.format(winner))
    plot_stats(stats, ylog=False, view=True)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#
#  ****** Running generation 0 ******
#
# fitness: -0.4431229962664751 counter: 3
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 29.79500823775595 counter: 1
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 328.11564762690017 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 292.77581874478403 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 444.6488818603696 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 260.86414816879505 counter: 0
# fitness: 201.62729495220648 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 443.84620659659464 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 279.0887312335284 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 426.96904624510194 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 403.5398964833399 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 308.65119291953766 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 515.3053768815297 counter: 0
# fitness: 4.101937676545602 counter: 1
# fitness: 131.2092879493008 counter: 0
# fitness: 558.5205300291482 counter: 0
# fitness: 278.80207946354085 counter: 0
# fitness: 231.9747143571599 counter: 0
# fitness: 194.3456643543328 counter: 0
# fitness: 178.26326887605012 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Population's average fitness: 275.60008 stdev: 156.95297
# Best fitness: 558.52053 - size: (8, 116) - species 3 - id 15
# Average adjusted fitness: 0.474
# Mean genetic distance 2.308, standard deviation 0.458
# Population of 20 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     5    201.6    0.362     0
#      2    0     8    515.3    0.479     0
#      3    0     7    558.5    0.582     0
# Total extinctions: 0
# Generation time: 23.316 sec
#
#  ****** Running generation 1 ******
#
# fitness: 5.0771743307604495 counter: 1
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 445.4419581885075 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 426.96904624510194 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 669.04971618817 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 426.2660134411018 counter: 0
# fitness: 188.24498375588385 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 408.44831537403763 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 235.74150851837442 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 1.544462684801657 counter: 1
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 447.2064209010939 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 163.94333665528856 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 446.34701837443697 counter: 0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# fitness: 320.95550395219004 counter: 0
# fitness: 5.589869661435197 counter: 1
# fitness: 479.4392205654393 counter: 0
# fitness: 481.38384958097583 counter: 0
# fitness: 265.1869354232435 counter: 0
# fitness: 394.39771485230114 counter: 0
# fitness: 325.9570956352618 counter: 0
# fitness: 399.2121087745106 counter: 0
# Population's average fitness: 326.82011 stdev: 175.20228
# Best fitness: 669.04972 - size: (8, 116) - species 3 - id 15
#
# Best individual in generation 1 meets fitness threshold - complexity: (8, 116)
#
# Best genome:
# Key: 15
# Fitness: 669.04971618817
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.4186487835686242, response=0.971290828865882, activation=sigmoid, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.16647139253363386, response=1.0311131067910837, activation=sigmoid, aggregation=product)
# 	2 DefaultNodeGene(key=2, bias=-0.9874310280935326, response=1.0335620583267306, activation=sigmoid, aggregation=min)
# 	3 DefaultNodeGene(key=3, bias=0.4611458632836209, response=1.0864207868599909, activation=sigmoid, aggregation=maxabs)
# 	4 DefaultNodeGene(key=4, bias=0.5125010213720154, response=0.9672856879065092, activation=sigmoid, aggregation=min)
# 	5 DefaultNodeGene(key=5, bias=-0.23873226161841588, response=1.011571996968648, activation=sigmoid, aggregation=max)
# 	6 DefaultNodeGene(key=6, bias=-0.36942471212795824, response=1.0083028924632698, activation=sigmoid, aggregation=product)
# 	7 DefaultNodeGene(key=7, bias=-1.119207532975451, response=0.9304474330836198, activation=sigmoid, aggregation=maxabs)
# Connections:
# 	DefaultConnectionGene(key=(-28, 4), weight=0.1341075475087523, enabled=True)
# 	DefaultConnectionGene(key=(-28, 6), weight=-0.5921450052498478, enabled=True)
# 	DefaultConnectionGene(key=(-28, 7), weight=0.3816164594230078, enabled=True)
# 	DefaultConnectionGene(key=(-27, 0), weight=1.016143254694367, enabled=True)
# 	DefaultConnectionGene(key=(-27, 1), weight=0.19043242211948117, enabled=True)
# 	DefaultConnectionGene(key=(-27, 3), weight=0.14473922388973648, enabled=True)
# 	DefaultConnectionGene(key=(-27, 5), weight=-1.0695712306348808, enabled=True)
# 	DefaultConnectionGene(key=(-27, 7), weight=-0.06166569016317619, enabled=True)
# 	DefaultConnectionGene(key=(-26, 4), weight=0.49901369002687224, enabled=True)
# 	DefaultConnectionGene(key=(-25, 1), weight=-0.33158333975061116, enabled=True)
# 	DefaultConnectionGene(key=(-25, 2), weight=-1.3840242040476793, enabled=True)
# 	DefaultConnectionGene(key=(-25, 3), weight=-0.5690274757668287, enabled=True)
# 	DefaultConnectionGene(key=(-25, 4), weight=-0.7595698313468827, enabled=True)
# 	DefaultConnectionGene(key=(-25, 5), weight=-1.1437874924245996, enabled=True)
# 	DefaultConnectionGene(key=(-25, 6), weight=1.3134935332649784, enabled=True)
# 	DefaultConnectionGene(key=(-25, 7), weight=1.7904590794982205, enabled=True)
# 	DefaultConnectionGene(key=(-24, 3), weight=0.21260594871391847, enabled=True)
# 	DefaultConnectionGene(key=(-24, 4), weight=2.046341912924718, enabled=True)
# 	DefaultConnectionGene(key=(-24, 5), weight=0.13214895018464834, enabled=True)
# 	DefaultConnectionGene(key=(-24, 6), weight=-0.7319638574943674, enabled=True)
# 	DefaultConnectionGene(key=(-23, 2), weight=-1.3875817270948285, enabled=True)
# 	DefaultConnectionGene(key=(-23, 4), weight=-0.06060012875429374, enabled=True)
# 	DefaultConnectionGene(key=(-23, 5), weight=1.405753231338121, enabled=True)
# 	DefaultConnectionGene(key=(-23, 6), weight=-0.4184519633229786, enabled=True)
# 	DefaultConnectionGene(key=(-23, 7), weight=-0.5870775354152419, enabled=True)
# 	DefaultConnectionGene(key=(-22, 0), weight=0.9507257590648701, enabled=True)
# 	DefaultConnectionGene(key=(-22, 2), weight=-0.9828766878295941, enabled=True)
# 	DefaultConnectionGene(key=(-22, 4), weight=-0.35881716915712036, enabled=True)
# 	DefaultConnectionGene(key=(-22, 5), weight=-0.10223725660038407, enabled=True)
# 	DefaultConnectionGene(key=(-22, 6), weight=-0.301552160065774, enabled=True)
# 	DefaultConnectionGene(key=(-22, 7), weight=2.425898864394604, enabled=True)
# 	DefaultConnectionGene(key=(-21, 0), weight=1.4232929230183475, enabled=True)
# 	DefaultConnectionGene(key=(-21, 1), weight=-0.0888058660781875, enabled=True)
# 	DefaultConnectionGene(key=(-21, 2), weight=-0.7547955405807516, enabled=True)
# 	DefaultConnectionGene(key=(-20, 4), weight=-0.43138194125973317, enabled=True)
# 	DefaultConnectionGene(key=(-20, 7), weight=-0.3949117498553192, enabled=True)
# 	DefaultConnectionGene(key=(-19, 1), weight=-1.1189983369489367, enabled=True)
# 	DefaultConnectionGene(key=(-19, 3), weight=-0.9594879741996906, enabled=True)
# 	DefaultConnectionGene(key=(-19, 4), weight=-0.2558607745716087, enabled=True)
# 	DefaultConnectionGene(key=(-19, 5), weight=0.28654825276513063, enabled=True)
# 	DefaultConnectionGene(key=(-18, 0), weight=1.2320835968855937, enabled=True)
# 	DefaultConnectionGene(key=(-18, 1), weight=-1.3707183710786033, enabled=True)
# 	DefaultConnectionGene(key=(-18, 3), weight=0.10248588363839489, enabled=True)
# 	DefaultConnectionGene(key=(-18, 4), weight=0.7378036585962563, enabled=True)
# 	DefaultConnectionGene(key=(-18, 5), weight=1.3797255333307634, enabled=True)
# 	DefaultConnectionGene(key=(-18, 6), weight=3.2381197039575755, enabled=True)
# 	DefaultConnectionGene(key=(-17, 0), weight=-0.9759511235293415, enabled=True)
# 	DefaultConnectionGene(key=(-17, 3), weight=-0.5988518654260939, enabled=True)
# 	DefaultConnectionGene(key=(-16, 0), weight=0.1623043406644838, enabled=True)
# 	DefaultConnectionGene(key=(-16, 6), weight=0.3079339663109495, enabled=True)
# 	DefaultConnectionGene(key=(-16, 7), weight=0.8438239716597197, enabled=True)
# 	DefaultConnectionGene(key=(-15, 0), weight=-1.4498536031372447, enabled=True)
# 	DefaultConnectionGene(key=(-15, 2), weight=-0.03652614480139399, enabled=True)
# 	DefaultConnectionGene(key=(-15, 4), weight=-2.2338601370554194, enabled=True)
# 	DefaultConnectionGene(key=(-14, 0), weight=-0.10672560242541579, enabled=True)
# 	DefaultConnectionGene(key=(-14, 1), weight=0.13021952273829332, enabled=True)
# 	DefaultConnectionGene(key=(-14, 3), weight=-0.8371726992374496, enabled=True)
# 	DefaultConnectionGene(key=(-13, 2), weight=0.932800715406578, enabled=True)
# 	DefaultConnectionGene(key=(-13, 5), weight=-0.4613143615155738, enabled=True)
# 	DefaultConnectionGene(key=(-13, 7), weight=0.7293684623477672, enabled=True)
# 	DefaultConnectionGene(key=(-12, 0), weight=0.36426328440672906, enabled=True)
# 	DefaultConnectionGene(key=(-12, 1), weight=0.9913806684039386, enabled=True)
# 	DefaultConnectionGene(key=(-12, 4), weight=-1.0284376275867386, enabled=True)
# 	DefaultConnectionGene(key=(-12, 5), weight=0.8819985374814634, enabled=True)
# 	DefaultConnectionGene(key=(-12, 6), weight=1.266949729465761, enabled=True)
# 	DefaultConnectionGene(key=(-11, 3), weight=0.6563963833852253, enabled=True)
# 	DefaultConnectionGene(key=(-11, 4), weight=-1.773395350391864, enabled=True)
# 	DefaultConnectionGene(key=(-11, 6), weight=1.0745601753883207, enabled=True)
# 	DefaultConnectionGene(key=(-11, 7), weight=0.989285461794601, enabled=True)
# 	DefaultConnectionGene(key=(-10, 0), weight=-0.008441680250331637, enabled=True)
# 	DefaultConnectionGene(key=(-10, 1), weight=-0.24832082502375066, enabled=True)
# 	DefaultConnectionGene(key=(-10, 3), weight=-0.3590669859982981, enabled=True)
# 	DefaultConnectionGene(key=(-10, 4), weight=0.9120782088014877, enabled=True)
# 	DefaultConnectionGene(key=(-10, 6), weight=0.3025706381068056, enabled=True)
# 	DefaultConnectionGene(key=(-10, 7), weight=-0.5408894958341498, enabled=True)
# 	DefaultConnectionGene(key=(-9, 1), weight=0.6408470494078906, enabled=True)
# 	DefaultConnectionGene(key=(-9, 5), weight=0.42866354889318303, enabled=True)
# 	DefaultConnectionGene(key=(-8, 0), weight=0.3624878241389251, enabled=True)
# 	DefaultConnectionGene(key=(-8, 1), weight=-0.7742612899865378, enabled=True)
# 	DefaultConnectionGene(key=(-8, 2), weight=-0.395604919022322, enabled=True)
# 	DefaultConnectionGene(key=(-8, 5), weight=0.9834299807832355, enabled=True)
# 	DefaultConnectionGene(key=(-8, 6), weight=-1.1745917812110935, enabled=True)
# 	DefaultConnectionGene(key=(-7, 0), weight=0.1156135794104751, enabled=True)
# 	DefaultConnectionGene(key=(-7, 3), weight=1.2358914502077298, enabled=True)
# 	DefaultConnectionGene(key=(-7, 4), weight=1.8636650305531177, enabled=True)
# 	DefaultConnectionGene(key=(-7, 5), weight=-1.497720951114758, enabled=True)
# 	DefaultConnectionGene(key=(-7, 6), weight=-0.4608833221774291, enabled=True)
# 	DefaultConnectionGene(key=(-6, 0), weight=-1.0993888239486191, enabled=True)
# 	DefaultConnectionGene(key=(-6, 3), weight=0.7832967688436088, enabled=True)
# 	DefaultConnectionGene(key=(-6, 4), weight=0.2415303343442302, enabled=True)
# 	DefaultConnectionGene(key=(-6, 5), weight=1.6249929474567828, enabled=True)
# 	DefaultConnectionGene(key=(-6, 6), weight=1.2010438838255342, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.6905786846654194, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.7041664687026542, enabled=True)
# 	DefaultConnectionGene(key=(-5, 4), weight=1.2563942034844626, enabled=True)
# 	DefaultConnectionGene(key=(-5, 7), weight=-0.32892496565232543, enabled=True)
# 	DefaultConnectionGene(key=(-4, 1), weight=-0.9768509305466023, enabled=True)
# 	DefaultConnectionGene(key=(-4, 2), weight=0.908606828098183, enabled=True)
# 	DefaultConnectionGene(key=(-4, 5), weight=1.3785004794842444, enabled=True)
# 	DefaultConnectionGene(key=(-4, 6), weight=1.5922756531373092, enabled=True)
# 	DefaultConnectionGene(key=(-4, 7), weight=-0.5348837446853598, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=-0.2972169208203509, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=0.869860802796526, enabled=True)
# 	DefaultConnectionGene(key=(-3, 2), weight=0.4000116736678183, enabled=True)
# 	DefaultConnectionGene(key=(-3, 5), weight=2.747817934142075, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=-0.4421301951311165, enabled=True)
# 	DefaultConnectionGene(key=(-2, 3), weight=-0.7448232648231117, enabled=True)
# 	DefaultConnectionGene(key=(-2, 4), weight=0.8533758264857494, enabled=True)
# 	DefaultConnectionGene(key=(-2, 5), weight=2.107114563348343, enabled=True)
# 	DefaultConnectionGene(key=(-2, 6), weight=0.4475327953329996, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=0.6343001510239349, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=-1.0576441553242772, enabled=True)
# 	DefaultConnectionGene(key=(0, 0), weight=1.797620766019324, enabled=True)
# 	DefaultConnectionGene(key=(2, 2), weight=1.2062515927029716, enabled=True)
# 	DefaultConnectionGene(key=(3, 3), weight=0.9648410255203975, enabled=True)
# 	DefaultConnectionGene(key=(4, 4), weight=-0.7336274214687589, enabled=True)
